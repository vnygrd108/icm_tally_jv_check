# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime
icm_sheet = pd.read_excel("icm.xlsx", engine="openpyxl")
icm_sheet = icm_sheet[['UID','RequestID','Department','BudgetItem','Amount','AmountRemarks','Vendor']]
icm_sheet.rename(columns={'UID': 'ICM UID',
                          'Department': 'ICM Department',
                          'Amount': 'ICM Amount',
                          'AmountRemarks': 'ICM Amount Remark',
                          'Vendor': 'ICM Vendor',
                          'BudgetItem' : 'ICM Budget Item'}, 
                 inplace=True)

icm_sheet.tail()
# Out:
#       ICM UID   RequestID                  ICM Department  \
# 0  4250000910  4250000910               RDD-Tribal Hostel
# 1  4250000908  4250000908               RDD-Tribal Hostel
# 2  4250000878  4250000878  RDD-SBI-Gram-Saksham-2024-2025
# 3  4250000874  4250000874  RDD-SBI-Gram-Saksham-2024-2025
# 4  4250000779  4250000779               RDD-Miscellaneous
#
#                        ICM Budget Item  ICM Amount  \
# 0                     Site Development       25000
# 1                     Site Development      399970
# 2  Well Deepening (fuel costs, boards)        1600
# 3         Construction of Common Ponds      278629
# 4                              RDD-034        8000
#
#                                    ICM Amount Remark  \
# 0  Payment of Machinery and Labour Contractor for...
# 1  Payment of Machinery and Labour Contractor for...
# 2  Diesel Transportation Expenses from ( Vikramga...
# 3  Pond Digging Expenses for Khadki Village. Date...
# 4  Advance Payment for Village Coordinator. Invoi...
#
#                                       ICM Vendor
# 0  Ramesh Ajinath Thakare ( Datta Construction )
# 1  Ramesh Ajinath Thakare ( Datta Construction )
# 2                           Rohidas Hemant Hadal
# 3                      Prathmesh Aniruddha Patil
# 4                        Kalpesh Devendra Vayada

# %%
tally_jv_sheet = pd.read_excel("tally.xlsx", skiprows=6, engine="openpyxl") 

tally_jv_sheet['Date'] = tally_jv_sheet['Date'].apply(lambda x: np.nan if pd.to_datetime(x, errors='coerce') is not pd.NaT else x)

# Rename column to 'Vendor'
tally_jv_sheet.rename(columns={'Date': 'Tally Vendor'}, inplace=True)

tally_jv_sheet = tally_jv_sheet.drop(index=tally_jv_sheet.index[0]).reset_index(drop=True)


tally_jv_sheet
# Out:
#                 Tally Vendor  \
# 0                        NaN
# 1                        NaN
# 2   Aaradhya Filling Station
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6         Datta Construction
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10        Datta Construction
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14      Rohidas Hemant Hadal
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18         Prathmesh A Patil
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22   Kalpesh Devendra Vayada
# 23                       NaN
# 24                    Total:
#
#                                           Particulars  Vch Type Vch No.  \
# 0                                    Site Development       NaN     NaN
# 1                                   RDD-Tribal Hostel  163458.0      Dr
# 2                                                 NaN  163458.0     NaN
# 3   Request ID :ST/RD/2500019 (UID: 4250000923) Di...       NaN     NaN
# 4                                    Site Development       NaN     NaN
# 5                                   RDD-Tribal Hostel   25000.0      Dr
# 6                                                 NaN   25000.0     NaN
# 7   UID No. 4250000910 Payment of Machinery and La...       NaN     NaN
# 8                                    Site Development       NaN     NaN
# 9                                   RDD-Tribal Hostel  399970.0      Dr
# 10                                                NaN  399970.0     NaN
# 11  UID No. 4250000908 Payment of Machinery and La...       NaN     NaN
# 12                Well Deepening (fuel costs, boards)       NaN     NaN
# 13                               RDD-SBI GRAM-SAKSHAM    1600.0      Dr
# 14                                                NaN    1600.0     NaN
# 15  UID No. 4250000878 Diesel Transportation Expen...       NaN     NaN
# 16                       Construction of Common Ponds       NaN     NaN
# 17                               RDD-SBI GRAM-SAKSHAM  278629.0      Dr
# 18                                                NaN  278629.0     NaN
# 19  UID No. 4250000874 Pond Digging Expenses for K...       NaN     NaN
# 20                                            RDD-034       NaN     NaN
# 21                                  RDD-Miscellaneous    8000.0      Dr
# 22                                                NaN    8000.0     NaN
# 23  UID No. 4250000779 Advance Payment for Village...       NaN     NaN
# 24                                                NaN       NaN     NaN
#
#       Debit Credit  Unnamed: 6
# 0   Journal      4    163458.0
# 1       NaN    NaN         NaN
# 2       NaN    NaN         NaN
# 3       NaN    NaN         NaN
# 4   Journal      5     25000.0
# 5       NaN    NaN         NaN
# 6       NaN    NaN         NaN
# 7       NaN    NaN         NaN
# 8   Journal      6    399970.0
# 9       NaN    NaN         NaN
# 10      NaN    NaN         NaN
# 11      NaN    NaN         NaN
# 12  Journal      7      1600.0
# 13      NaN    NaN         NaN
# 14      NaN    NaN         NaN
# 15      NaN    NaN         NaN
# 16  Journal      8    278629.0
# 17      NaN    NaN         NaN
# 18      NaN    NaN         NaN
# 19      NaN    NaN         NaN
# 20  Journal      9      8000.0
# 21      NaN    NaN         NaN
# 22      NaN    NaN         NaN
# 23      NaN    NaN         NaN
# 24   876657    NaN         NaN

# %%
tally_jv_sheet = tally_jv_sheet[~tally_jv_sheet.astype(str).apply(lambda row: row.str.contains("Professional Tax", na=False)).any(axis=1)]
tally_jv_sheet = tally_jv_sheet[~tally_jv_sheet.astype(str).apply(lambda row: row.str.contains("Provident Fund Employee", na=False)).any(axis=1)]
tally_jv_sheet = tally_jv_sheet.reset_index(drop=True)
tally_jv_sheet
# Out:
#                 Tally Vendor  \
# 0                        NaN
# 1                        NaN
# 2   Aaradhya Filling Station
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6         Datta Construction
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10        Datta Construction
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14      Rohidas Hemant Hadal
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18         Prathmesh A Patil
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22   Kalpesh Devendra Vayada
# 23                       NaN
# 24                    Total:
#
#                                           Particulars  Vch Type Vch No.  \
# 0                                    Site Development       NaN     NaN
# 1                                   RDD-Tribal Hostel  163458.0      Dr
# 2                                                 NaN  163458.0     NaN
# 3   Request ID :ST/RD/2500019 (UID: 4250000923) Di...       NaN     NaN
# 4                                    Site Development       NaN     NaN
# 5                                   RDD-Tribal Hostel   25000.0      Dr
# 6                                                 NaN   25000.0     NaN
# 7   UID No. 4250000910 Payment of Machinery and La...       NaN     NaN
# 8                                    Site Development       NaN     NaN
# 9                                   RDD-Tribal Hostel  399970.0      Dr
# 10                                                NaN  399970.0     NaN
# 11  UID No. 4250000908 Payment of Machinery and La...       NaN     NaN
# 12                Well Deepening (fuel costs, boards)       NaN     NaN
# 13                               RDD-SBI GRAM-SAKSHAM    1600.0      Dr
# 14                                                NaN    1600.0     NaN
# 15  UID No. 4250000878 Diesel Transportation Expen...       NaN     NaN
# 16                       Construction of Common Ponds       NaN     NaN
# 17                               RDD-SBI GRAM-SAKSHAM  278629.0      Dr
# 18                                                NaN  278629.0     NaN
# 19  UID No. 4250000874 Pond Digging Expenses for K...       NaN     NaN
# 20                                            RDD-034       NaN     NaN
# 21                                  RDD-Miscellaneous    8000.0      Dr
# 22                                                NaN    8000.0     NaN
# 23  UID No. 4250000779 Advance Payment for Village...       NaN     NaN
# 24                                                NaN       NaN     NaN
#
#       Debit Credit  Unnamed: 6
# 0   Journal      4    163458.0
# 1       NaN    NaN         NaN
# 2       NaN    NaN         NaN
# 3       NaN    NaN         NaN
# 4   Journal      5     25000.0
# 5       NaN    NaN         NaN
# 6       NaN    NaN         NaN
# 7       NaN    NaN         NaN
# 8   Journal      6    399970.0
# 9       NaN    NaN         NaN
# 10      NaN    NaN         NaN
# 11      NaN    NaN         NaN
# 12  Journal      7      1600.0
# 13      NaN    NaN         NaN
# 14      NaN    NaN         NaN
# 15      NaN    NaN         NaN
# 16  Journal      8    278629.0
# 17      NaN    NaN         NaN
# 18      NaN    NaN         NaN
# 19      NaN    NaN         NaN
# 20  Journal      9      8000.0
# 21      NaN    NaN         NaN
# 22      NaN    NaN         NaN
# 23      NaN    NaN         NaN
# 24   876657    NaN         NaN

# %%
# Create group numbers (each group of 4 rows)
tally_jv_sheet['Group'] = tally_jv_sheet.index // 4

# Merge using groupby (aggregating each column as a list)
tally_jv_sheet_merged = tally_jv_sheet.groupby('Group', as_index=False).agg(lambda x: list(x))

# Drop 'Group' column if not needed
tally_jv_sheet_merged.drop(columns=['Group'], inplace=True)

# Remove NaN values from lists in each column
tally_jv_sheet_merged = tally_jv_sheet_merged.apply(lambda col: col.map(lambda x: [i for i in x if pd.notna(i)]))

tally_jv_sheet_merged
# Out:
#                  Tally Vendor  \
# 0  [Aaradhya Filling Station]
# 1        [Datta Construction]
# 2        [Datta Construction]
# 3      [Rohidas Hemant Hadal]
# 4         [Prathmesh A Patil]
# 5   [Kalpesh Devendra Vayada]
# 6                    [Total:]
#
#                                          Particulars              Vch Type  \
# 0  [Site Development, RDD-Tribal Hostel, Request ...  [163458.0, 163458.0]
# 1  [Site Development, RDD-Tribal Hostel, UID No. ...    [25000.0, 25000.0]
# 2  [Site Development, RDD-Tribal Hostel, UID No. ...  [399970.0, 399970.0]
# 3  [Well Deepening (fuel costs, boards), RDD-SBI ...      [1600.0, 1600.0]
# 4  [Construction of Common Ponds, RDD-SBI GRAM-SA...  [278629.0, 278629.0]
# 5  [RDD-034, RDD-Miscellaneous, UID No. 425000077...      [8000.0, 8000.0]
# 6                                                 []                    []
#
#   Vch No.      Debit Credit  Unnamed: 6
# 0    [Dr]  [Journal]    [4]  [163458.0]
# 1    [Dr]  [Journal]    [5]   [25000.0]
# 2    [Dr]  [Journal]    [6]  [399970.0]
# 3    [Dr]  [Journal]    [7]    [1600.0]
# 4    [Dr]  [Journal]    [8]  [278629.0]
# 5    [Dr]  [Journal]    [9]    [8000.0]
# 6      []   [876657]     []          []

# %%
# Find max list length in 'Particulars' and 'Vch Type' to create new columns
max_length = max(tally_jv_sheet_merged['Particulars'].apply(len).max(), 
                 tally_jv_sheet_merged['Vch Type'].apply(len).max())

# Create new columns dynamically
for i in range(max_length):
    tally_jv_sheet_merged[f'Particulars_{i+1}'] = tally_jv_sheet_merged['Particulars'].apply(lambda x: x[i] if i < len(x) else np.nan)
    tally_jv_sheet_merged[f'Vch Type_{i+1}'] = tally_jv_sheet_merged['Vch Type'].apply(lambda x: x[i] if i < len(x) else np.nan)

# Drop original columns
tally_jv_sheet_merged.drop(columns=['Particulars', 'Vch Type'], inplace=True)

tally_jv_sheet_merged
# Out:
#                  Tally Vendor Vch No.      Debit Credit  Unnamed: 6  \
# 0  [Aaradhya Filling Station]    [Dr]  [Journal]    [4]  [163458.0]
# 1        [Datta Construction]    [Dr]  [Journal]    [5]   [25000.0]
# 2        [Datta Construction]    [Dr]  [Journal]    [6]  [399970.0]
# 3      [Rohidas Hemant Hadal]    [Dr]  [Journal]    [7]    [1600.0]
# 4         [Prathmesh A Patil]    [Dr]  [Journal]    [8]  [278629.0]
# 5   [Kalpesh Devendra Vayada]    [Dr]  [Journal]    [9]    [8000.0]
# 6                    [Total:]      []   [876657]     []          []
#
#                          Particulars_1  Vch Type_1         Particulars_2  \
# 0                     Site Development    163458.0     RDD-Tribal Hostel
# 1                     Site Development     25000.0     RDD-Tribal Hostel
# 2                     Site Development    399970.0     RDD-Tribal Hostel
# 3  Well Deepening (fuel costs, boards)      1600.0  RDD-SBI GRAM-SAKSHAM
# 4         Construction of Common Ponds    278629.0  RDD-SBI GRAM-SAKSHAM
# 5                              RDD-034      8000.0     RDD-Miscellaneous
# 6                                  NaN         NaN                   NaN
#
#    Vch Type_2                                      Particulars_3  Vch Type_3
# 0    163458.0  Request ID :ST/RD/2500019 (UID: 4250000923) Di...         NaN
# 1     25000.0  UID No. 4250000910 Payment of Machinery and La...         NaN
# 2    399970.0  UID No. 4250000908 Payment of Machinery and La...         NaN
# 3      1600.0  UID No. 4250000878 Diesel Transportation Expen...         NaN
# 4    278629.0  UID No. 4250000874 Pond Digging Expenses for K...         NaN
# 5      8000.0  UID No. 4250000779 Advance Payment for Village...         NaN
# 6         NaN                                                NaN         NaN

# %%
tally_jv_sheet_merged = tally_jv_sheet_merged[['Tally Vendor','Particulars_1','Vch Type_2','Particulars_2','Particulars_3']]
tally_jv_sheet_merged = tally_jv_sheet_merged.iloc[:-1]
tally_df = tally_jv_sheet_merged.rename(columns={'Particulars_1':'Tally Budget Item','Vch Type_2':'Tally Amount','Particulars_2':'Tally Department','Particulars_3':'Tally Amount Remarks'})
tally_df['Tally Vendor'] = tally_df['Tally Vendor'].apply(lambda x: x[0] if isinstance(x, list) and len(x) == 1 else x)

tally_df['Tally UID'] = tally_df['Tally Amount Remarks'].astype(str).str.extract(r'(?<!\d)(\d{10})(?!\d)')

tally_df['Tally UID'] = tally_df['Tally UID'].astype('Int64')
tally_df
# Out:
#                Tally Vendor                    Tally Budget Item  \
# 0  Aaradhya Filling Station                     Site Development
# 1        Datta Construction                     Site Development
# 2        Datta Construction                     Site Development
# 3      Rohidas Hemant Hadal  Well Deepening (fuel costs, boards)
# 4         Prathmesh A Patil         Construction of Common Ponds
# 5   Kalpesh Devendra Vayada                              RDD-034
#
#    Tally Amount      Tally Department  \
# 0      163458.0     RDD-Tribal Hostel
# 1       25000.0     RDD-Tribal Hostel
# 2      399970.0     RDD-Tribal Hostel
# 3        1600.0  RDD-SBI GRAM-SAKSHAM
# 4      278629.0  RDD-SBI GRAM-SAKSHAM
# 5        8000.0     RDD-Miscellaneous
#
#                                 Tally Amount Remarks   Tally UID
# 0  Request ID :ST/RD/2500019 (UID: 4250000923) Di...  4250000923
# 1  UID No. 4250000910 Payment of Machinery and La...  4250000910
# 2  UID No. 4250000908 Payment of Machinery and La...  4250000908
# 3  UID No. 4250000878 Diesel Transportation Expen...  4250000878
# 4  UID No. 4250000874 Pond Digging Expenses for K...  4250000874
# 5  UID No. 4250000779 Advance Payment for Village...  4250000779

# %%
# Step 1: Merge and filter columns
merged_df = icm_sheet.merge(tally_df, left_on="ICM UID", right_on="Tally UID", how="outer")

merged_df = merged_df[['ICM UID', 'Tally UID', 'ICM Department', 'Tally Department',
                       'ICM Budget Item', 'Tally Budget Item', 'ICM Amount', 'Tally Amount',
                       'ICM Amount Remark', 'Tally Amount Remarks', 'ICM Vendor', 'Tally Vendor']]

merged_df
# Out:
#         ICM UID   Tally UID                  ICM Department  \
# 0  4.250001e+09  4250000779               RDD-Miscellaneous
# 1  4.250001e+09  4250000874  RDD-SBI-Gram-Saksham-2024-2025
# 2  4.250001e+09  4250000878  RDD-SBI-Gram-Saksham-2024-2025
# 3  4.250001e+09  4250000908               RDD-Tribal Hostel
# 4  4.250001e+09  4250000910               RDD-Tribal Hostel
# 5           NaN  4250000923                             NaN
#
#        Tally Department                      ICM Budget Item  \
# 0     RDD-Miscellaneous                              RDD-034
# 1  RDD-SBI GRAM-SAKSHAM         Construction of Common Ponds
# 2  RDD-SBI GRAM-SAKSHAM  Well Deepening (fuel costs, boards)
# 3     RDD-Tribal Hostel                     Site Development
# 4     RDD-Tribal Hostel                     Site Development
# 5     RDD-Tribal Hostel                                  NaN
#
#                      Tally Budget Item  ICM Amount  Tally Amount  \
# 0                              RDD-034      8000.0        8000.0
# 1         Construction of Common Ponds    278629.0      278629.0
# 2  Well Deepening (fuel costs, boards)      1600.0        1600.0
# 3                     Site Development    399970.0      399970.0
# 4                     Site Development     25000.0       25000.0
# 5                     Site Development         NaN      163458.0
#
#                                    ICM Amount Remark  \
# 0  Advance Payment for Village Coordinator. Invoi...
# 1  Pond Digging Expenses for Khadki Village. Date...
# 2  Diesel Transportation Expenses from ( Vikramga...
# 3  Payment of Machinery and Labour Contractor for...
# 4  Payment of Machinery and Labour Contractor for...
# 5                                                NaN
#
#                                 Tally Amount Remarks  \
# 0  UID No. 4250000779 Advance Payment for Village...
# 1  UID No. 4250000874 Pond Digging Expenses for K...
# 2  UID No. 4250000878 Diesel Transportation Expen...
# 3  UID No. 4250000908 Payment of Machinery and La...
# 4  UID No. 4250000910 Payment of Machinery and La...
# 5  Request ID :ST/RD/2500019 (UID: 4250000923) Di...
#
#                                       ICM Vendor              Tally Vendor
# 0                        Kalpesh Devendra Vayada   Kalpesh Devendra Vayada
# 1                      Prathmesh Aniruddha Patil         Prathmesh A Patil
# 2                           Rohidas Hemant Hadal      Rohidas Hemant Hadal
# 3  Ramesh Ajinath Thakare ( Datta Construction )        Datta Construction
# 4  Ramesh Ajinath Thakare ( Datta Construction )        Datta Construction
# 5                                            NaN  Aaradhya Filling Station

# %%
import pandas as pd

# Assuming df is your DataFrame

# Define ICM and Tally column pairs
column_pairs = [
    ('ICM UID', 'Tally UID'),
    ('ICM Department', 'Tally Department'),
    ('ICM Budget Item', 'Tally Budget Item'),
    ('ICM Amount', 'Tally Amount'),
    ('ICM Amount Remark', 'Tally Amount Remarks'),
    ('ICM Vendor', 'Tally Vendor')
]

def compare_row(row):
    match_cols = []
    unmatch_cols = []

    for icm_col, tally_col in column_pairs:
        icm_val = row[icm_col]
        tally_val = row[tally_col]

        # Compare after converting both to string and stripping extra whitespace
        if str(icm_val).strip() == str(tally_val).strip():
            match_cols.append(icm_col)
        else:
            unmatch_cols.append(icm_col)

    match_status = 'Matched' if not unmatch_cols else 'Unmatched'

    return pd.Series([match_status, match_cols, unmatch_cols], index=['Match_Status', 'Match_Columns', 'Unmatch_Column'])

# Apply comparison across rows
merged_df[['Match_Status', 'Match_Columns', 'Unmatch_Column']] = merged_df.apply(compare_row, axis=1)

# %%
merged_df = merged_df[[
    'Match_Status', 'Match_Columns', 'Unmatch_Column',
    'ICM Budget Item', 'Tally Budget Item',
    'ICM Department', 'Tally Department',
    'ICM Vendor', 'Tally Vendor',
    'ICM Amount Remark', 'Tally Amount Remarks',
    'ICM UID', 'Tally UID',
    'ICM Amount', 'Tally Amount'
]]
merged_df
# Out:
#   Match_Status                                      Match_Columns  \
# 0    Unmatched  [ICM Department, ICM Budget Item, ICM Amount, ...
# 1    Unmatched                      [ICM Budget Item, ICM Amount]
# 2    Unmatched          [ICM Budget Item, ICM Amount, ICM Vendor]
# 3    Unmatched      [ICM Department, ICM Budget Item, ICM Amount]
# 4    Unmatched      [ICM Department, ICM Budget Item, ICM Amount]
# 5    Unmatched                                                 []
#
#                                       Unmatch_Column  \
# 0                       [ICM UID, ICM Amount Remark]
# 1  [ICM UID, ICM Department, ICM Amount Remark, I...
# 2       [ICM UID, ICM Department, ICM Amount Remark]
# 3           [ICM UID, ICM Amount Remark, ICM Vendor]
# 4           [ICM UID, ICM Amount Remark, ICM Vendor]
# 5  [ICM UID, ICM Department, ICM Budget Item, ICM...
#
#                        ICM Budget Item                    Tally Budget Item  \
# 0                              RDD-034                              RDD-034
# 1         Construction of Common Ponds         Construction of Common Ponds
# 2  Well Deepening (fuel costs, boards)  Well Deepening (fuel costs, boards)
# 3                     Site Development                     Site Development
# 4                     Site Development                     Site Development
# 5                                  NaN                     Site Development
#
#                    ICM Department      Tally Department  \
# 0               RDD-Miscellaneous     RDD-Miscellaneous
# 1  RDD-SBI-Gram-Saksham-2024-2025  RDD-SBI GRAM-SAKSHAM
# 2  RDD-SBI-Gram-Saksham-2024-2025  RDD-SBI GRAM-SAKSHAM
# 3               RDD-Tribal Hostel     RDD-Tribal Hostel
# 4               RDD-Tribal Hostel     RDD-Tribal Hostel
# 5                             NaN     RDD-Tribal Hostel
#
#                                       ICM Vendor              Tally Vendor  \
# 0                        Kalpesh Devendra Vayada   Kalpesh Devendra Vayada
# 1                      Prathmesh Aniruddha Patil         Prathmesh A Patil
# 2                           Rohidas Hemant Hadal      Rohidas Hemant Hadal
# 3  Ramesh Ajinath Thakare ( Datta Construction )        Datta Construction
# 4  Ramesh Ajinath Thakare ( Datta Construction )        Datta Construction
# 5                                            NaN  Aaradhya Filling Station
#
#                                    ICM Amount Remark  \
# 0  Advance Payment for Village Coordinator. Invoi...
# 1  Pond Digging Expenses for Khadki Village. Date...
# 2  Diesel Transportation Expenses from ( Vikramga...
# 3  Payment of Machinery and Labour Contractor for...
# 4  Payment of Machinery and Labour Contractor for...
# 5                                                NaN
#
#                                 Tally Amount Remarks       ICM UID  \
# 0  UID No. 4250000779 Advance Payment for Village...  4.250001e+09
# 1  UID No. 4250000874 Pond Digging Expenses for K...  4.250001e+09
# 2  UID No. 4250000878 Diesel Transportation Expen...  4.250001e+09
# 3  UID No. 4250000908 Payment of Machinery and La...  4.250001e+09
# 4  UID No. 4250000910 Payment of Machinery and La...  4.250001e+09
# 5  Request ID :ST/RD/2500019 (UID: 4250000923) Di...           NaN
#
#     Tally UID  ICM Amount  Tally Amount
# 0  4250000779      8000.0        8000.0
# 1  4250000874    278629.0      278629.0
# 2  4250000878      1600.0        1600.0
# 3  4250000908    399970.0      399970.0
# 4  4250000910     25000.0       25000.0
# 5  4250000923         NaN      163458.0

# %%
# Get current date and time in DD-MM-YYYY_HH:MM:SS format
timestamp = datetime.now().strftime("%d-%m-%Y_%H-%M-%S")

# Generate filename with timestamp
filename = f"ICM Tally Entry Check Sheet_{timestamp}.xlsx"

# Save the DataFrame
merged_df.to_excel(filename, index=False, engine="openpyxl")
